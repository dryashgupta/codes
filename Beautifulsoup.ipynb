# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter location: ')
if len(url) < 1 :
    url = 'http://py4e-data.dr-chuck.net/comments_753314.json'

print('Retrieving',url)

uh = urllib.request.urlopen(url,context=ctx)

data = uh.read().decode()
print('Retrieved',len(data),'characters')
n = 0
my_list =[]
info = json.loads(data)

for item in info['comments']:
    if item['count']:
        n += 1
        my_list.append(item['count'])
print('count',n)
print('sum:',sum(my_list))
# Out:
# Enter location:
# Retrieving http://py4e-data.dr-chuck.net/comments_753314.json
# Retrieved 2714 characters
# count 50
# sum: 2600

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if key is False:
    key = 42
    service_url = 'http://py4e-data.dr-chuck.net/json?'
else :
    service_url = 'https://maps.googleapis.com/maps/api/geocode/json?'


# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
while True:
    address = input('Enter location: ')
    if len(address) < 1 :break

    url = service_url + urllib.parse.urlencode({'address':address,'key':key})    
    print('Retrieving',url)

    uh = urllib.request.urlopen(url,context=ctx)

    data = uh.read().decode()
    print('Retrieved',len(data),'characters')

    try:
        js = json.loads(data)
    except: 
        js = None
    
    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue
    print(json.dumps(js, indent=4))
    print('place_id:',js['results'][0]['place_id'])
# Out:
# Enter location: Taj Mahal
# Retrieving http://py4e-data.dr-chuck.net/json?address=Taj+Mahal&key=42
# Retrieved 2388 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dharmapuri",
#                     "short_name": "Dharmapuri",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Forest Colony",
#                     "short_name": "Forest Colony",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_2"
#                     ]
#                 },
#                 {
#                     "long_name": "Tajganj",
#                     "short_name": "Tajganj",
#                     "types": [
#                         "political",
# ...

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if key is False:
    key = 42
    service_url = 'http://py4e-data.dr-chuck.net/json?'
else :
    service_url = 'https://maps.googleapis.com/maps/api/geocode/json?'


# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
while True:
    address = input('Enter location: ')
    if len(address) < 1 :break

    url = service_url + urllib.parse.urlencode({'address':address,'key':key})    
    print('Retrieving',url)

    uh = urllib.request.urlopen(url,context=ctx)

    data = uh.read().decode()
    print('Retrieved',len(data),'characters')

    try:
        js = json.loads(data)
    except: 
        js = None
    
    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue
    print(js['results'][0]['formatted_address'])
    #headers = dict(uh.getheaders())
    #print('headers',headers)
# Out:
# Enter location: Taj Mahal India
# Retrieving http://py4e-data.dr-chuck.net/json?address=Taj+Mahal+India&key=42
# Retrieved 2505 characters
# 1250 E Republic Rd, Springfield, MO 65804, USA
# Enter location: Taj Mahal
# Retrieving http://py4e-data.dr-chuck.net/json?address=Taj+Mahal&key=42
# Retrieved 2388 characters
# Dharmapuri, Forest Colony, Tajganj, Agra, Uttar Pradesh 282001, India
# Enter location: Hawa Mahal
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hawa+Mahal&key=42
# Retrieved 2597 characters
# Hawa Mahal Rd, Badi Choupad, J.D.A. Market, Kanwar Nagar, Jaipur, Rajasthan 302002, India
